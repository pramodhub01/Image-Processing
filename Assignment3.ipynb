# %% [markdown]
# 1.  Take an image of size 512*512,  sub-sampled down it to size 256*256, 128*128, 64*64, 32*32
#     pixels. The number of allowable gray levels was kept at 256. Sub-sampling
#     is achieved by deleting every other row and column.
#
# 2. Apply Re-sampling, on images obtained in Q.1 by row and column duplication
#     256*256 Image resampled into 512*512 pixels by row and column duplication.
#     128*128 Image resampled into 512*512 pixels by row and column duplication.
#     64*64  Image resampled into 512*512 pixels by row and column duplication.
#     32*32  Image resampled into 512*512 pixels by row and column duplication.
# 3. Write a program to perform basic arithmetic operations on two images:
#     Addition
#     Subtraction
#     Multiplication
#     Averaging
# 4. Write a program to perform basic logic operations on input image(s):
#     AND
#     OR
#     NOT

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
original_image = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\Lenna.jpg", cv2.IMREAD_GRAYSCALE)
image_256 = original_image[::2,::2]
image_128 = image_256[::2,::2]
image_64 = image_128[::2,::2]
image_32 = image_64[::2,::2]

plt.figure(figsize=(10,4))

plt.subplot(1,5,1)
plt.title("original_512*512")
plt.imshow(original_image,cmap='gray')

plt.subplot(1,5,2)
plt.title("image_256*256")
plt.imshow(image_256,cmap='gray')
7
plt.subplot(1,5,3)

plt.title("image_128*128")
plt.imshow(image_128,cmap='gray')

plt.subplot(1,5,4)
plt.title("image_64*64")
plt.imshow(image_64,cmap='gray')

plt.subplot(1,5,5)
plt.title("image_32*32")
plt.imshow(image_32,cmap='gray')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np

# Define a function to resample the image by duplicating rows and columns
def resample(image, target_size):
    rows, cols = image.shape
    resampled_image = np.zeros(target_size, dtype=np.uint8)
    row_ratio = target_size[0] // rows
    col_ratio = target_size[1] // cols
    for i in range(rows):
        for j in range(cols):
            resampled_image[i*row_ratio:(i+1)*row_ratio, j*col_ratio:(j+1)*col_ratio] = image[i, j]
    return resampled_image


original_image = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\Lenna.jpg", cv2.IMREAD_GRAYSCALE)
image_256 = original_image[::2,::2]
image_128 = image_256[::2,::2]
image_64 = image_128[::2,::2]
image_32 = image_64[::2,::2]


# Load the subsampled images
subsampled_256 = image_256
subsampled_128 = image_128
subsampled_64 = image_64
subsampled_32 = image_32

# Resample the images to 512x512 by duplicating rows and columns
resampled_512_256 = resample(subsampled_256, (512, 512))
resampled_512_128 = resample(subsampled_128, (512, 512))
resampled_512_64 = resample(subsampled_64, (512, 512))
resampled_512_32 = resample(subsampled_32, (512, 512))


plt.subplot(2,3,1)
plt.title("original")
plt.imshow(original_image,cmap='gray')

plt.subplot(2,3,2)
plt.title("resampled_256")
plt.imshow(resampled_512_256,cmap='gray')

plt.subplot(2,3,3)
plt.title("resampled_128")
plt.imshow(resampled_512_128,cmap='gray')

plt.subplot(2,3,4)
plt.title("resampled_64")
plt.imshow(resampled_512_64,cmap='gray')

plt.subplot(2,3,5)
plt.title("resampled_32")
plt.imshow(resampled_512_32,cmap='gray')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

original_image = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\Lenna.jpg", cv2.IMREAD_GRAYSCALE)
image_256 = original_image[::2,::2]
image_128 = image_256[::2,::2]
image_64 = image_128[::2,::2]
image_32 = image_64[::2,::2]

# Load the subsampled images
subsampled_256 = image_256
subsampled_128 = image_128
subsampled_64 = image_64
subsampled_32 = image_32

# Define a function to resample the image by duplicating rows and columns
def resample(image, target_size):
    rows, cols = image.shape
    resampled_image = np.zeros(target_size, dtype=np.uint8)
    row_ratio = target_size[0] // rows
    col_ratio = target_size[1] // cols
    for i in range(rows):
        for j in range(cols):
            resampled_image[i*row_ratio:(i+1)*row_ratio, j*col_ratio:(j+1)*col_ratio] = image[i, j]
    return resampled_image

# Resample the images to 512x512 by duplicating rows and columns
resampled_512_256 = resample(subsampled_256, (512, 512))
resampled_512_128 = resample(subsampled_128, (512, 512))
resampled_512_64 = resample(subsampled_64, (512, 512))
resampled_512_32 = resample(subsampled_32, (512, 512))

# Display the resampled images using matplotlib.pyplot
plt.figure(figsize=(10, 5))

plt.subplot(2, 3, 1)
plt.title("Original")
plt.imshow(original_image, cmap='gray')

plt.subplot(2, 3, 2)
plt.title("Resampled 256x256")
plt.imshow(resampled_512_256, cmap='gray')

plt.subplot(2, 3, 3)
plt.title("Resampled 128x128")
plt.imshow(resampled_512_128, cmap='gray')

plt.subplot(2, 3, 4)
plt.title("Resampled 64x64")
plt.imshow(resampled_512_64, cmap='gray')

plt.subplot(2, 3, 5)
plt.title("Resampled 32x32")
plt.imshow(resampled_512_32, cmap='gray')

plt.tight_layout()
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Read the two images
img1 = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\Lenna.jpg")
img2 = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\WhatsApp Image 2024-03-12 at 10.55.07_4518c1df.jpg")

# Ensure that both images have the same dimensions
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

# Add the two images together
img3 = cv2.add(img2, img1)

# Display the result using matplotlib.pyplot
plt.figure(figsize=(10,4))

plt.title("Added image")
plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Read the two images
img1 = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\Lenna.jpg")
img2 = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\LennaGrayscale.jpg")

# Ensure that both images have the same dimensions
img2 = cv2.resize(img2, (img1.shape[0], img1.shape[1]))

# Subtract the second image from the first image
img_diff = cv2.subtract(img1, img2)

# Display the result
plt.subplot(1,3,1)
plt.title("Image_1")
plt.axis('off')  # Hide axis
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))

plt.subplot(1,3,2)
plt.title("Image_2")
plt.axis('off')  # Hide axis
plt.imshow(img2)

plt.subplot(1,3,3)
plt.title("Image_1-Image_2")
plt.imshow(cv2.cvtColor(img_diff, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Hide axis
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Read the two images
img1 = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\Lenna.jpg")
img2 = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\LennaGrayscale.jpg")

# Ensure that both images have the same dimensions
img2 = cv2.resize(img2, (img1.shape[0], img1.shape[1]))

# Multiply the two images together
img_mul = cv2.multiply(img1, img2)

# Display the result
plt.imshow(cv2.cvtColor(img_mul, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Hide axis
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the two images
img1 = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\Lenna.jpg")
img2 = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\bhul.jpeg")

# Ensure that both images have the same dimensions
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

# Calculate the average of the two images
img_avg = cv2.addWeighted(img1, 0.5, img2, 0.5, 0)

# Display the result
plt.imshow(cv2.cvtColor(img_avg, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Hide axis
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the two images
img1 = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\Lenna.jpg")
img2 = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\bhul.jpeg")

# Resize img2 to match img1's dimensions
img2_resized = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

# Convert images to grayscale
img1_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2_gray = cv2.cvtColor(img2_resized, cv2.COLOR_BGR2GRAY)

# Perform thresholding to binarize the images
_, img1_binary = cv2.threshold(img1_gray, 127, 255, cv2.THRESH_BINARY)
_, img2_binary = cv2.threshold(img2_gray, 127, 255, cv2.THRESH_BINARY)

# Perform bitwise AND operation
result = cv2.bitwise_and(img1_binary, img2_binary)

# Display the result
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Hide axis
plt.show()

# %%
import cv2
import numpy as np

# Read the two images
img1 = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\Lenna.jpg")
img2 = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\bhul.jpeg")

# Resize img2 to match img1's dimensions
img2_resized = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

# Convert images to grayscale
img1_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2_gray = cv2.cvtColor(img2_resized, cv2.COLOR_BGR2GRAY)

# Perform thresholding to binarize the images
_, img1_binary = cv2.threshold(img1_gray, 127, 255, cv2.THRESH_BINARY)
_, img2_binary = cv2.threshold(img2_gray, 127, 255, cv2.THRESH_BINARY)

# Perform bitwise OR operation
result = cv2.bitwise_or(img1_binary, img2_binary)

# Display the result
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Hide axis
plt.show()

# %%
import cv2
import numpy as np

# Read the image
img = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\Lenna.jpg")

# Convert the image to grayscale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Invert the pixel values using bitwise NOT operation
img_not = cv2.bitwise_not(img_gray)

# Display the result
plt.subplot(1,2,1)
plt.title("Oringinal Image")
plt.imshow( img_gray,cmap='gray')

plt.subplot(1,2,2)
plt.title("NOT Image")
plt.imshow( img_not, cmap='gray')
plt.axis('off')  # Hide axis
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread(r"C:\Users\HP\Desktop\DIPLAB\Testimage\LennaGrayscale.jpg", cv2.IMREAD_GRAYSCALE)

# Define parameters
gamma_values = [0.1, 0.5, 1.5, 2.0, 5.0]
root_value = 3
power_value = 2

# Apply Power Law Transformation with different gamma values
power_law_transformed = []
for gamma in gamma_values:
    gamma_corrected = np.power(image / 255.0, gamma) * 255
    power_law_transformed.append(gamma_corrected)

# Apply Nth Root Transformation
root_transformed = np.power(image, 1/root_value)

# Apply Nth Power Transformation
power_transformed = np.power(image, power_value)

# Display the transformed images
plt.figure(figsize=(12, 8))

# Display Power Law Transformed Images
for i, gamma in enumerate(gamma_values):
    plt.subplot(2, 4, i + 1)
    plt.title(f"Power Law (Gamma = {gamma})")
    plt.imshow(power_law_transformed[i], cmap='gray')
    plt.axis('off')

# Display Original Image
plt.subplot(2, 4, 6)
plt.title("Original Image")
plt.imshow(image, cmap='gray')
plt.axis('off')

# Display Nth Root Transformed Image
plt.subplot(2, 4, 7)
plt.title(f"Nth Root (n = {root_value})")
plt.imshow(root_transformed, cmap='gray')
plt.axis('off')

# Display Nth Power Transformed Image
plt.subplot(2, 4, 8)
plt.title(f"Nth Power (n = {power_value})")
plt.imshow(power_transformed, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()
